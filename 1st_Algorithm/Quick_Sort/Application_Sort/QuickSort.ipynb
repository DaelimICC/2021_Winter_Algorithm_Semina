# %% [markdown]
# # 서울시 쓰레기 종량제 봉투 최대/최소 비용 구하기

# %% [markdown]
# ### 모듈 호출

# %%
import json
from urllib.parse import urlencode, quote_plus
from urllib.request import urlopen, Request
import pandas as pd
from pandas.core.frame import DataFrame
import numpy as np
from pandas import json_normalize
import requests

# %% [markdown]
# ### REST API 호출

# %%
url = 'http://api.data.go.kr/openapi/tn_pubr_public_weighted_envlp_api'

queryParams = '?' + urlencode(
    {quote_plus('ServiceKey'): 'APIKEY',
     quote_plus('pageNo'): '1', quote_plus('numOfRows'): '50', quote_plus('type'): 'json', quote_plus('CTPRVN_NM') : '서울특별시'
     })

request = Request(url + queryParams)

request.get_method = lambda: 'GET'

response_body = urlopen(request, timeout=60).read()

print(response_body)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE","type":"json"},"body":{"items":[{"ctprvnNm":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","signguNm":"\xea\xb4\x80\xec\x95\x85\xea\xb5\xac","weightedEnvlpType":"\xea\xb7\x9c\xea\xb2\xa9\xeb\xb4\x89\xed\x88\xac","weightedEnvlpMthd":"\xec\x86\x8c\xea\xb0\x81\xec\x9a\xa9","weightedEnvlpPrpos":"\xec\x83\x9d\xed\x99\x9c\xec\x93\xb0\xeb\xa0\x88\xea\xb8\xb0","weightedEnvlpTrget":"\xea\xb0\x80\xec\xa0\x95\xec\x9a\xa9","price1":"0","price1Half":"0","price2":"0","price2Half":"0","price3":"90","price5":"130","price10":"250","price20":"490","price30":"740","price50":"1250","price60":"0","price75":"1880","price100":"0","price120":"0","price125":"0","chrgDeptNm":"\xec\xb2\xad\xec\x86\x8c\xed\x96\x89\xec\xa0\x95\xea\xb3\xbc","phoneNumber":"02-879-6206","referenceDate":"2021-10-15","insttCode":"3200000"},{"ctprvnNm":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","signguNm":"\xea\xb4\x80\xec\x95\x85\xea\xb5\xac","weightedEnvlpType":"\xea\xb7\x9c\xea\xb2\xa9\xeb\xb4\x89\xed\x88\xac","weightedEnvlpMthd":"\xec\x86\x8c\xea\xb0\x81\xec\x9a\xa9","weightedEnvlpPrpos":"\xec\x9d\x8c\xec\x8b\x9d\xeb\xac\xbc\xec\x93\xb0\xeb\xa0\x88\xea\xb8\xb0","weightedEnvlpTrget":"\xea\xb0\x80\xec\xa0\x95\xec\x9a\xa9","price1":"100","price1Half":"0","price2":"190","price2Half":"0","price3":"300","price5":"500","price10":"0","price20":"0","price30":"0","price50":"0","price60":"0","price75":"0","price100":"0","price120":"0","price125":"0","chrgDeptNm":"\xec\xb2\xad\xec\x86\x8c\xed\x96\x89\xec\xa0\x95\xea\xb3\xbc","phoneNumber":"02-879-6206","referenceDate":"2021-10-15","insttCode":"3200000"},{"ctprvnNm":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","signguNm":"\xec\x84\x9c\xec\xb4\x88\xea\xb5\xac","weightedEnvlpType":"\xea\xb7\x9c\xea\xb2\xa9\xeb\xb4\x89\xed\x88\xac","weightedEnvlpMthd":"\xec\x86\x8c\xea\xb0\x81\xec\x9a\xa9","weightedEnvlpPrpos":"\xec\x83\x9d\xed\x99\x9c\xec\x93\xb0\xeb\xa0\x88\xea\xb8\xb0","weightedEnvlpTrget":"\xea\xb0\x80\xec\xa0\x95\xec\x9a\xa9","price1":"0","price1Half":"0","price2":"60","price2Half":"0","price3":"0","price5":"130","price10":"250","price20":"490","price30":"0","price50":"1250","price60":"0","price75":"0","price100":"0","price120":"0","price125":"0","chrgDeptNm":"\xec\xb2\xad\xec\x86\x8c\xed\x96\x89\xec\xa0\x95\xea\xb3\xbc","phoneNumber":"02-2155-6723","referenceDate":"2021-10-05","insttCode":"3210000"},{"ctprvnNm":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","signguNm":"\xec\x86\xa1\xed\x8c\x8c\xea\xb5\xac","weightedEnvlpType":"\xea\xb7\x9c\xea\xb2\xa9\xeb\xb4\x89\xed\x88\xac","weightedEnvlpMthd":"\xeb\xa7\xa4\xeb\xa6\xbd\xec\x9a\xa9","weightedEnvlpPrpos":"\xec\x83\x9d\xed\x99\x9c\xec\x93\xb0\xeb\xa0\x88\xea\xb8\xb0","weightedEnvlpTrget":"\xec\x82\xac\xec\x97\x85\xec\x9e\xa5\xec\x9a\xa9","price1":"0","price1Half":"0","price2":"0","price2Half":"0","price3":"0","price5":"0","price10":"0","price20":"820","price30":"0","price50":"2040","price60":"0","price75":"3300","price100":"0","price120":"0","price125":"0","chrgDeptNm":"\xec\x9e\x90\xec\x9b\x90\xec\x88\x9c\xed\x99\x98\xea\xb3\xbc","phoneNumber":"02-2147-2840","referenceDate":"2021-02-19","insttCode":"3230000"},{"ctprvnNm":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","signguNm":"\xec\x86\xa1\xed\x8c\x8c\xea\xb5\xac","weightedEnvlpType":"\xec\x9e\xac\xec\x82\xac\xec\x9a\xa9\xea\xb7\x9c\xea\xb2\xa9\xeb\xb4\x89\xed\x88\xac","weightedEnvlpMthd":"\xec\x86\x8c\xea\xb0\x81\xec\x9a\xa9","weightedEnvlpPrpos":"\xec\x83\x9d\xed\x99\x9c\xec\x93\xb0\xeb\xa0\x88\xea\xb8\xb0","weightedEnvlpTrget":"\xea\xb0\x80\xec\xa0\x95\xec\x9a\xa9","price1":"0","price1Half":"0","price2":"0","price2Half":"0","price3":"0","price5":"0","price10":"250","price20":"490","price30":"0","price50":"0","price60":"0","price75":"0","price100":"0","price120":"0","price125":"0","chrgDeptNm":"\xec\x9e\x90\xec\x9b\x90\xec\x88\x9c\xed\x99\x98\xea\xb3\xbc","phoneNumber":"02-2 ...

# %% [markdown]
# ### API 디코딩 및 JSON 파일 저장

# %%
tempDic = json.loads(response_body)

data = json.dumps(tempDic, indent=4, ensure_ascii=False)
print(data)

with open('./TrashPackPrice.json', 'w', encoding='utf-8') as file:
    file.write(data)
# Out:
# {
#     "response": {
#         "header": {
#             "resultCode": "00",
#             "resultMsg": "NORMAL_SERVICE",
#             "type": "json"
#         },
#         "body": {
#             "items": [
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "관악구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "90",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-879-6206",
#                     "referenceDate": "2021-10-15",
#                     "insttCode": "3200000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "관악구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "190",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "0",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-879-6206",
#                     "referenceDate": "2021-10-15",
#                     "insttCode": "3200000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "서초구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "60",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2155-6723",
#                     "referenceDate": "2021-10-05",
#                     "insttCode": "3210000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "820",
#                     "price30": "0",
#                     "price50": "2040",
#                     "price60": "0",
#                     "price75": "3300",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "기타",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "김장용봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "2000",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "은평구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "2500",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-351-7563",
#                     "referenceDate": "2021-04-20",
#                     "insttCode": "3110000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "은평구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "80",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "190",
#                     "price10": "380",
#                     "price20": "760",
#                     "price30": "0",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "2500",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-351-7563",
#                     "referenceDate": "2021-04-20",
#                     "insttCode": "3110000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "은평구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-351-7563",
#                     "referenceDate": "2021-04-20",
#                     "insttCode": "3110000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "은평구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-351-7563",
#                     "referenceDate": "2021-04-20",
#                     "insttCode": "3110000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "은평구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "200",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "1000",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-351-7563",
#                     "referenceDate": "2021-04-20",
#                     "insttCode": "3110000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "중구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-3396-5486",
#                     "referenceDate": "2021-10-19",
#                     "insttCode": "3010000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "중구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "2000",
#                     "price60": "0",
#                     "price75": "3000",
#                     "price100": "4000",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-3396-5486",
#                     "referenceDate": "2021-10-19",
#                     "insttCode": "3010000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "800",
#                     "price30": "0",
#                     "price50": "2000",
#                     "price60": "0",
#                     "price75": "3000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "송파구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "820",
#                     "price30": "0",
#                     "price50": "2040",
#                     "price60": "0",
#                     "price75": "3300",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2147-2840",
#                     "referenceDate": "2021-02-19",
#                     "insttCode": "3230000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "서초구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "영업용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "520",
#                     "price30": "0",
#                     "price50": "1330",
#                     "price60": "0",
#                     "price75": "2000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2155-6723",
#                     "referenceDate": "2021-10-05",
#                     "insttCode": "3210000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "서초구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "기타",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "200",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "1000",
#                     "price20": "2000",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2155-6723",
#                     "referenceDate": "2021-10-05",
#                     "insttCode": "3210000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "서초구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2155-6723",
#                     "referenceDate": "2021-10-05",
#                     "insttCode": "3210000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "서초구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "기타",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2155-6723",
#                     "referenceDate": "2021-10-05",
#                     "insttCode": "3210000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "중구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "90",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "2500",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-3396-5486",
#                     "referenceDate": "2021-10-19",
#                     "insttCode": "3010000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "중구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "90",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-3396-5486",
#                     "referenceDate": "2021-10-19",
#                     "insttCode": "3010000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성북구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2241-4405",
#                     "referenceDate": "2021-03-18",
#                     "insttCode": "3070000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성북구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "520",
#                     "price30": "780",
#                     "price50": "1330",
#                     "price60": "0",
#                     "price75": "2000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2241-4405",
#                     "referenceDate": "2021-03-18",
#                     "insttCode": "3070000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성북구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "기타",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "190",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "0",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2241-4405",
#                     "referenceDate": "2021-03-18",
#                     "insttCode": "3070000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성북구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "기타",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "1020",
#                     "price20": "2040",
#                     "price30": "3060",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2241-4405",
#                     "referenceDate": "2021-03-18",
#                     "insttCode": "3070000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성북구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2241-4405",
#                     "referenceDate": "2021-03-18",
#                     "insttCode": "3070000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "구로구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-860-2904",
#                     "referenceDate": "2021-10-28",
#                     "insttCode": "3160000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "구로구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-860-2904",
#                     "referenceDate": "2021-10-28",
#                     "insttCode": "3160000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "양천구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "2500",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "서울특별시 양천구 청소행정과",
#                     "phoneNumber": "02-2620-3420",
#                     "referenceDate": "2021-06-21",
#                     "insttCode": "3140000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "90",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "90",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "520",
#                     "price30": "780",
#                     "price50": "1330",
#                     "price60": "0",
#                     "price75": "2000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "520",
#                     "price30": "780",
#                     "price50": "1330",
#                     "price60": "0",
#                     "price75": "2000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "190",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "0",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "1020",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "1020",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "성동구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2286-5528",
#                     "referenceDate": "2021-06-18",
#                     "insttCode": "3030000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "구로구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-860-2904",
#                     "referenceDate": "2021-10-28",
#                     "insttCode": "3160000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "구로구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "190",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "1000",
#                     "price20": "2000",
#                     "price30": "3000",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-860-2904",
#                     "referenceDate": "2021-10-28",
#                     "insttCode": "3160000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "구로구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "2000",
#                     "price60": "0",
#                     "price75": "3000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-860-2904",
#                     "referenceDate": "2021-10-28",
#                     "insttCode": "3160000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "노원구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용+사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "90",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "2500",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2116-3800",
#                     "referenceDate": "2021-09-13",
#                     "insttCode": "3100000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "노원구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용+사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "1020",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "자원순환과",
#                     "phoneNumber": "02-2116-3800",
#                     "referenceDate": "2021-09-13",
#                     "insttCode": "3100000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "동대문구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "130",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "740",
#                     "price50": "1250",
#                     "price60": "0",
#                     "price75": "1880",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2127-4725",
#                     "referenceDate": "2021-05-03",
#                     "insttCode": "3050000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "동대문구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "음식물쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "100",
#                     "price1Half": "0",
#                     "price2": "190",
#                     "price2Half": "0",
#                     "price3": "300",
#                     "price5": "500",
#                     "price10": "1000",
#                     "price20": "0",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2127-4725",
#                     "referenceDate": "2021-05-03",
#                     "insttCode": "3050000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "동대문구",
#                     "weightedEnvlpType": "규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "사업장용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "0",
#                     "price20": "800",
#                     "price30": "0",
#                     "price50": "2000",
#                     "price60": "0",
#                     "price75": "3000",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2127-4725",
#                     "referenceDate": "2021-05-03",
#                     "insttCode": "3050000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "동대문구",
#                     "weightedEnvlpType": "재사용규격봉투",
#                     "weightedEnvlpMthd": "소각용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "250",
#                     "price20": "490",
#                     "price30": "0",
#                     "price50": "0",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2127-4725",
#                     "referenceDate": "2021-05-03",
#                     "insttCode": "3050000"
#                 },
#                 {
#                     "ctprvnNm": "서울특별시",
#                     "signguNm": "동대문구",
#                     "weightedEnvlpType": "특수규격마대",
#                     "weightedEnvlpMthd": "매립용",
#                     "weightedEnvlpPrpos": "생활쓰레기",
#                     "weightedEnvlpTrget": "가정용",
#                     "price1": "0",
#                     "price1Half": "0",
#                     "price2": "0",
#                     "price2Half": "0",
#                     "price3": "0",
#                     "price5": "0",
#                     "price10": "1020",
#                     "price20": "2040",
#                     "price30": "0",
#                     "price50": "5100",
#                     "price60": "0",
#                     "price75": "0",
#                     "price100": "0",
#                     "price120": "0",
#                     "price125": "0",
#                     "chrgDeptNm": "청소행정과",
#                     "phoneNumber": "02-2127-4725",
#                     "referenceDate": "2021-05-03",
#                     "insttCode": "3050000"
#                 }
#             ],
#             "totalCount": "104",
#             "numOfRows": "50",
#             "pageNo": "1"
#         }
#     }
# }

# %% [markdown]
# ### 데이터 전처리

# %%
with open('./TrashPackPrice.json', 'r', encoding='utf-8') as file:
    json_sample = json.load(file)

# 불필요한 정보 제거
json_data = pd.json_normalize(json_sample['response']['body']['items'])
json_data = json_data.drop(['chrgDeptNm', 'phoneNumber', 'referenceDate', 'insttCode', 'weightedEnvlpMthd', 'ctprvnNm'], axis=1)
json_data = json_data.drop(['price125', 'price120', 'price100'], axis=1)
json_data = json_data.drop(['price1', 'price2', 'price3', 'price5', 'price1Half', 'price2Half', 'price75', 'price60', 'price50', 'price30', 'price10'], axis=1)

# 사업장용 봉투 제거
temp_index = json_data[json_data['weightedEnvlpTrget'] == '사업장용'].index
json_data = json_data.drop(temp_index)

# 영업용 봉투 제거
temp_index = json_data[json_data['weightedEnvlpTrget'] == '영업용'].index
json_data = json_data.drop(temp_index)

# 용도 불문 기타 봉투 제거
temp_index = json_data[json_data['weightedEnvlpTrget'] == '기타'].index
json_data = json_data.drop(temp_index)

# 20리터 종량제 봉투를 제외한 나머지 봉투 제거
temp_index = json_data[json_data['price20'] == '0'].index
json_data = json_data.drop(temp_index)

# 음식물 쓰레기 봉투 제거
temp_index = json_data[json_data['weightedEnvlpPrpos'] == '음식물쓰레기'].index
json_data = json_data.drop(temp_index)

json_data
# Out:
#    signguNm weightedEnvlpType weightedEnvlpPrpos weightedEnvlpTrget price20
# 0       관악구              규격봉투              생활쓰레기                가정용     490
# 2       서초구              규격봉투              생활쓰레기                가정용     490
# 4       송파구           재사용규격봉투              생활쓰레기                가정용     490
# 5       송파구           재사용규격봉투              생활쓰레기                가정용     490
# 8       은평구              규격봉투              생활쓰레기                가정용     490
# 9       은평구              규격봉투              생활쓰레기                가정용     760
# 10      은평구           재사용규격봉투              생활쓰레기                가정용     490
# 11      은평구            특수규격마대              생활쓰레기                가정용    2040
# 13       중구            특수규격마대              생활쓰레기                가정용    2040
# 19      서초구           재사용규격봉투              생활쓰레기                가정용     490
# 21       중구              규격봉투              생활쓰레기                가정용     490
# 22       중구           재사용규격봉투              생활쓰레기                가정용     490
# 23      성북구              규격봉투              생활쓰레기                가정용     490
# 27      성북구           재사용규격봉투              생활쓰레기                가정용     490
# 28      구로구           재사용규격봉투              생활쓰레기                가정용     490
# 29      구로구            특수규격마대              생활쓰레기                가정용    2040
# 30      양천구              규격봉투              생활쓰레기                가정용     490
# 31      성동구              규격봉투              생활쓰레기                가정용     490
# 32      성동구              규격봉투              생활쓰레기                가정용     490
# 36      성동구            특수규격마대              생활쓰레기                가정용    2040
# 37      성동구            특수규격마대              생활쓰레기                가정용    2040
# 38      성동구           재사용규격봉투              생활쓰레기                가정용     490
# 39      성동구           재사용규격봉투              생활쓰레기                가정용     490
# 40      구로구              규격봉투              생활쓰레기                가정용     490
# 43      노원구              규격봉투              생활쓰레기           가정용+사업장용     490
# 44      노원구            특수규격마대              생활쓰레기           가정용+사업장용    2040
# 45     동대문구              규격봉투              생활쓰레기                가정용     490
# 48     동대문구           재사용규격봉투              생활쓰레기                가정용     490
# 49     동대문구            특수규격마대              생활쓰레기                가정용    2040

# %% [markdown]
# ### 퀵정렬 함수 선언

# %%
def partition(list, start, end):
    pivot = list[start]
    left = start + 1
    right = end
    done = False
    while not done:
        while left <= right and list[left] <= pivot:
            left += 1
        while left <= right and list[right] > pivot:
            right -= 1
        if right < left:
            done = True
        else:
            list[left], list[right] = list[right], list[left]
    list[start], list[right] = list[right], list[start]  # 피봇 교환
    return right

def QuickSort(list, start, end):
    stack = []
    stack.append(start)
    stack.append(end)

    while stack:
        end = stack.pop()
        start = stack.pop()
        pivot = partition(list, start, end)

        if pivot - 1 > start:
            stack.append(start)
            stack.append(pivot - 1)

        if pivot + 1 < end:
            stack.append(pivot + 1)
            stack.append(end)

    return list

# %% [markdown]
# ### 데이터프레임값 리스트로 변환 및 정렬

# %%
price_list = list(np.array(json_data['price20'].tolist()))
price_list = list(map(int, price_list))
price_list = QuickSort(price_list, 0, len(price_list)-1)
price_list = list(map(str, price_list))

# %% [markdown]
# ### 쓰레기 봉투 최소 값

# %%
minPrice = price_list[0]

search_index = json_data[json_data['price20'] == minPrice].index
json_data.loc[search_index]
# Out:
#    signguNm weightedEnvlpType weightedEnvlpPrpos weightedEnvlpTrget price20
# 0       관악구              규격봉투              생활쓰레기                가정용     490
# 2       서초구              규격봉투              생활쓰레기                가정용     490
# 4       송파구           재사용규격봉투              생활쓰레기                가정용     490
# 5       송파구           재사용규격봉투              생활쓰레기                가정용     490
# 8       은평구              규격봉투              생활쓰레기                가정용     490
# 10      은평구           재사용규격봉투              생활쓰레기                가정용     490
# 19      서초구           재사용규격봉투              생활쓰레기                가정용     490
# 21       중구              규격봉투              생활쓰레기                가정용     490
# 22       중구           재사용규격봉투              생활쓰레기                가정용     490
# 23      성북구              규격봉투              생활쓰레기                가정용     490
# 27      성북구           재사용규격봉투              생활쓰레기                가정용     490
# 28      구로구           재사용규격봉투              생활쓰레기                가정용     490
# 30      양천구              규격봉투              생활쓰레기                가정용     490
# 31      성동구              규격봉투              생활쓰레기                가정용     490
# 32      성동구              규격봉투              생활쓰레기                가정용     490
# 38      성동구           재사용규격봉투              생활쓰레기                가정용     490
# 39      성동구           재사용규격봉투              생활쓰레기                가정용     490
# 40      구로구              규격봉투              생활쓰레기                가정용     490
# 43      노원구              규격봉투              생활쓰레기           가정용+사업장용     490
# 45     동대문구              규격봉투              생활쓰레기                가정용     490
# 48     동대문구           재사용규격봉투              생활쓰레기                가정용     490

# %% [markdown]
# ### 쓰레기 봉투 최대 값

# %%
maxPrice = price_list[len(price_list)-1]

search_index = json_data[json_data['price20'] == maxPrice].index
json_data.loc[search_index]
# Out:
#    signguNm weightedEnvlpType weightedEnvlpPrpos weightedEnvlpTrget price20
# 11      은평구            특수규격마대              생활쓰레기                가정용    2040
# 13       중구            특수규격마대              생활쓰레기                가정용    2040
# 29      구로구            특수규격마대              생활쓰레기                가정용    2040
# 36      성동구            특수규격마대              생활쓰레기                가정용    2040
# 37      성동구            특수규격마대              생활쓰레기                가정용    2040
# 44      노원구            특수규격마대              생활쓰레기           가정용+사업장용    2040
# 49     동대문구            특수규격마대              생활쓰레기                가정용    2040
